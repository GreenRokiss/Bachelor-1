# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !unzip "/content/drive/MyDrive/custom_mask_model/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/mask_data/mask_images/mask_373.txt
#   inflating: darknet/mask_data/mask_images/mask_374.jpg
#   inflating: darknet/mask_data/mask_images/mask_374.txt
#   inflating: darknet/mask_data/mask_images/mask_375.jpg
#   inflating: darknet/mask_data/mask_images/mask_375.txt
#   inflating: darknet/mask_data/mask_images/mask_376.jpg
#   inflating: darknet/mask_data/mask_images/mask_376.txt
#   inflating: darknet/mask_data/mask_images/mask_377.jpg
#   inflating: darknet/mask_data/mask_images/mask_377.txt
#   inflating: darknet/mask_data/mask_images/mask_378.jpg
#   inflating: darknet/mask_data/mask_images/mask_378.txt
#   inflating: darknet/mask_data/mask_images/mask_379.jpg
#   inflating: darknet/mask_data/mask_images/mask_379.txt
#   inflating: darknet/mask_data/mask_images/mask_38.jpg
#   inflating: darknet/mask_data/mask_images/mask_38.txt
#   inflating: darknet/mask_data/mask_images/mask_380.jpg
# ...

# %%
# %cd /content/darknet/
# Out:
# /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 53 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (359 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_285.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_775.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/000080.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/mask_31.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_885.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/000265.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/000244.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_167.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/000103.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_1384.txt to Unix format...
# ...

# %%
# !chmod +x /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4-tiny.cfg yolov4-tiny.weights data/person.jpg
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...

# %%
# !rm /content/darknet/backup -r

# %%
# !ln -s /content/drive/MyDrive/custom_mask_model/mask_weights/backup /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !./darknet detector train mask_data/mask.data yolov4-tiny.cfg yolov4-tiny.conv.29 -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.001108, iou_loss = 0.000000, total_loss = 0.001108
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.716013), count: 3, class_loss = 0.597371, iou_loss = 6.490542, total_loss = 7.087913
#  total_bbox = 790456, rewritten_bbox = 0.029730 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.809170), count: 1, class_loss = 0.141578, iou_loss = 0.040587, total_loss = 0.182166
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 790457, rewritten_bbox = 0.029730 %
# ...
