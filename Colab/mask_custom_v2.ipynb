# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !unzip "/content/drive/MyDrive/custom_mask_model_v3/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/mask_data_old/mask_images/mask_373.txt
#   inflating: darknet/mask_data_old/mask_images/mask_374.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_374.txt
#   inflating: darknet/mask_data_old/mask_images/mask_375.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_375.txt
#   inflating: darknet/mask_data_old/mask_images/mask_376.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_376.txt
#   inflating: darknet/mask_data_old/mask_images/mask_377.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_377.txt
#   inflating: darknet/mask_data_old/mask_images/mask_378.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_378.txt
#   inflating: darknet/mask_data_old/mask_images/mask_379.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_379.txt
#   inflating: darknet/mask_data_old/mask_images/mask_38.jpg
#   inflating: darknet/mask_data_old/mask_images/mask_38.txt
# ...

# %%
# %cd /content/darknet/
# Out:
# /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 59 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (670 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: converting file ./mask_data/mask_images/correct_mask_419.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./mask_data/mask_images/correct_mask_42.jpg
# dos2unix: converting file ./mask_data/mask_images/correct_mask_42.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./mask_data/mask_images/correct_mask_420.jpg
# dos2unix: converting file ./mask_data/mask_images/correct_mask_420.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./mask_data/mask_images/correct_mask_421.jpg
# dos2unix: converting file ./mask_data/mask_images/correct_mask_421.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./mask_data/mask_images/correct_mask_422.jpg
# ...

# %%
# !chmod +x /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !rm /content/darknet/backup -r

# %%
# !ln -s /content/drive/MyDrive/custom_mask_model_v3/mask_weights/backup /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !./darknet detector train mask_data/mask.data yolov4.cfg /content/drive/MyDrive/custom_mask_model_v3/mask_weights/backup/yolov4_best.weights -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  5981: 1.773508, 1.486081 avg loss, 0.000130 rate, 13.369664 seconds, 382784 images, 0.306256 hours left
# Loaded: 0.000071 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.006466, iou_loss = 0.000000, total_loss = 0.006466
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.631643), count: 3, class_loss = 2.634512, iou_loss = 8.765661, total_loss = 11.400173
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.796413), count: 8, class_loss = 3.269215, iou_loss = 2.447781, total_loss = 5.716996
#  total_bbox = 250949, rewritten_bbox = 0.008767 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# ...
